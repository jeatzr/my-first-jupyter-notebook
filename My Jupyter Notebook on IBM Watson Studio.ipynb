# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b>José Enrique Atiénzar</b>
#
# Teacher of Web Development

# %% [markdown]
# <i>I'm interested on data science because i think that is a future (and pressent) profession.</i>

# %% [markdown]
# <h3>I'm creating my first python app. My hello world!</h3>

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# <h4>IBM Tools</h4>
# <ul>
#     <li>SPSS</li>
#     <li>Watson Studio</li>
#     <li>Auto AI</li>
# </ul>
#
# ***
#
# <a href="https://es.wikipedia.org/wiki/Ciencia_de_datos">Data Science</a>
# ***
